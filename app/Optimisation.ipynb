# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt 
import numpy as np

# %%
X,y = make_classification(n_samples = 10000, n_informative= 10, random_state=2022)

# %%
# spliting the data set into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2022)

# print the train and test split shape
print("X Train set: ", X_train.shape, "X Test set: ", X_test.shape, 
      "y Train set: ", y_train.shape, "y Test set: ", y_test.shape)
# Out:
# X Train set:  (8000, 20) X Test set:  (2000, 20) y Train set:  (8000,) y Test set:  (2000,)

# %%
model = tf.keras.Sequential(
    [tf.keras.layers.Dense(10, activation='relu', input_shape=(X_train.shape[1],)),
     tf.keras.layers.Dense(10, activation='relu'),
     tf.keras.layers.Dense(1, activation='sigmoid')]
)

model.compile(loss
    ='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), verbose = 1)
# Out:
# Epoch 1/20
# /workspaces/AI-NN/.venv/lib/python3.13/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6503 - loss: 0.6391 - val_accuracy: 0.7895 - val_loss: 0.4787
# Epoch 2/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8487 - loss: 0.3661 - val_accuracy: 0.8805 - val_loss: 0.3012
# Epoch 3/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8971 - loss: 0.2604 - val_accuracy: 0.9010 - val_loss: 0.2487
# Epoch 4/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9151 - loss: 0.2204 - val_accuracy: 0.9100 - val_loss: 0.2233
# Epoch 5/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9241 - loss: 0.1966 - val_accuracy: 0.9235 - val_loss: 0.2031
# Epoch 6/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9327 - loss: 0.1802 - val_accuracy: 0.9325 - val_loss: 0.1889
# Epoch 7/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9389 - loss: 0.1679 - val_accuracy: 0.9345 - val_loss: 0.1760
# Epoch 8/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9420 - loss: 0.1586 - val_accuracy: 0.9375 - val_loss: 0.1688
# Epoch 9/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9440 - loss: 0.1508 - val_accuracy: 0.9440 - val_loss: 0.1598
# Epoch 10/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9475 - loss: 0.1445 - val_accuracy: 0.9440 - val_loss: 0.1540
# Epoch 11/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9516 - loss: 0.1393 - val_accuracy: 0.9465 - val_loss: 0.1481
# Epoch 12/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9535 - loss: 0.1350 - val_accuracy: 0.9455 - val_loss: 0.1433
# Epoch 13/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9540 - loss: 0.1320 - val_accuracy: 0.9505 - val_loss: 0.1382
# Epoch 14/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9561 - loss: 0.1289 - val_accuracy: 0.9510 - val_loss: 0.1355
# Epoch 15/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9556 - loss: 0.1267 - val_accuracy: 0.9530 - val_loss: 0.1318
# Epoch 16/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9566 - loss: 0.1238 - val_accuracy: 0.9555 - val_loss: 0.1286
# Epoch 17/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9591 - loss: 0.1211 - val_accuracy: 0.9545 - val_loss: 0.1269
# Epoch 18/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9584 - loss: 0.1197 - val_accuracy: 0.9565 - val_loss: 0.1233
# Epoch 19/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9601 - loss: 0.1173 - val_accuracy: 0.9600 - val_loss: 0.1214
# Epoch 20/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9601 - loss: 0.1152 - val_accuracy: 0.9580 - val_loss: 0.1196

# %%
# plot the loss of the models
fig, ax = plt.subplots(figsize=(12,8))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.xticks(np.arange(0,20, step= 1))
plt.legend(['train', 'test'], loc= 'upper right')
plt.show()
